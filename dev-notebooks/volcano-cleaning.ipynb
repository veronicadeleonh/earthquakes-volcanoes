# %%
import kagglehub
import os
import pandas as pd

path = kagglehub.dataset_download("jessemostipak/volcano-eruptions")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/veronica/.cache/kagglehub/datasets/jessemostipak/volcano-eruptions/versions/1

# %%
print(os.listdir(path))

eruptions_path = os.path.join(path, "eruptions.csv")
volcano_path = os.path.join(path, "volcano.csv")

eruptions = pd.read_csv(eruptions_path)
volcano_types = pd.read_csv(volcano_path)

display(eruptions)
display(volcano_types)
# Out:
# ['eruptions.csv', 'sulfur.csv', 'volcano.csv', 'events.csv', 'tree_rings.csv']
#        volcano_number            volcano_name  eruption_number  \
# 0              266030                 Soputan            22354
# 1              343100              San Miguel            22355
# 2              233020  Fournaise, Piton de la            22343
# 3              345020      Rincon de la Vieja            22346
# 4              353010              Fernandina            22347
# ...               ...                     ...              ...
# 11173          324020     Craters of the Moon            21101
# 11174          222161            Igwisi Hills            22141
# 11175          357121            Quetrupillan            22351
# 11176          357121            Quetrupillan            22352
# 11177          390090                Saunders            21099
#
#         eruption_category area_of_activity  vei  start_year  start_month  \
# 0      Confirmed Eruption              NaN  NaN      2020.0          3.0
# 1      Confirmed Eruption              NaN  NaN      2020.0          2.0
# 2      Confirmed Eruption              NaN  NaN      2020.0          2.0
# 3      Confirmed Eruption              NaN  NaN      2020.0          1.0
# 4      Confirmed Eruption              NaN  NaN      2020.0          1.0
# ...                   ...              ...  ...         ...          ...
# 11173  Confirmed Eruption      Sunset cone  0.0    -10060.0          NaN
# 11174  Confirmed Eruption       NE Volcano  1.0    -10450.0          NaN
# 11175  Confirmed Eruption              NaN  3.0    -10658.0          NaN
# 11176  Confirmed Eruption              NaN  3.0    -11345.0          NaN
# 11177  Confirmed Eruption              NaN  0.0         NaN          NaN
#
#        start_day     evidence_method_dating  end_year  end_month  end_day  \
# 0           23.0    Historical Observations    2020.0        4.0      2.0
# 1           22.0    Historical Observations    2020.0        2.0     22.0
# 2           10.0    Historical Observations    2020.0        4.0      6.0
# 3           31.0    Historical Observations    2020.0        4.0     17.0
# 4           12.0    Historical Observations    2020.0        1.0     12.0
# ...          ...                        ...       ...        ...      ...
# 11173        NaN  Radiocarbon (uncorrected)       NaN        NaN      NaN
# 11174        NaN           Surface Exposure       NaN        NaN      NaN
# 11175        NaN    Radiocarbon (corrected)       NaN        NaN      NaN
# 11176        NaN    Radiocarbon (corrected)       NaN        NaN      NaN
# 11177        NaN                        NaN       NaN        NaN      NaN
#
#        latitude  longitude
# 0         1.112    124.737
# 1        13.434    -88.269
# 2       -21.244     55.708
# 3        10.830    -85.324
# 4        -0.370    -91.550
# ...         ...        ...
# 11173    43.420   -113.500
# 11174    -4.889     31.933
# 11175   -39.496    -71.722
# 11176   -39.496    -71.722
# 11177   -57.800    -26.483
#
# [11178 rows x 15 columns]
#      volcano_number              volcano_name primary_volcano_type  \
# 0            283001                       Abu            Shield(s)
# 1            355096                Acamarachi        Stratovolcano
# 2            342080                Acatenango    Stratovolcano(es)
# 3            213004           Acigol-Nevsehir              Caldera
# 4            321040                     Adams        Stratovolcano
# ..              ...                       ...                  ...
# 953          300242                    Zimina    Stratovolcano(es)
# 954          341061  Zitacuaro-Valle de Bravo              Caldera
# 955          221020              Zubair Group               Shield
# 956          221021                     Zukur               Shield
# 957          327120              Zuni-Bandera       Volcanic field
#
#     last_eruption_year        country                          region  \
# 0                -6850          Japan         Japan, Taiwan, Marianas
# 1              Unknown          Chile                   South America
# 2                 1972      Guatemala      México and Central America
# 3                -2080         Turkey  Mediterranean and Western Asia
# 4                  950  United States          Canada and Western USA
# ..                 ...            ...                             ...
# 953            Unknown         Russia     Kamchatka and Mainland Asia
# 954              -3050         Mexico      México and Central America
# 955               2013          Yemen              Africa and Red Sea
# 956            Unknown          Yemen              Africa and Red Sea
# 957              -1170  United States          Canada and Western USA
#
#                                  subregion  latitude  longitude  elevation  \
# 0                                   Honshu    34.500    131.600        641
# 1    Northern Chile, Bolivia and Argentina   -23.292    -67.618       6023
# 2                                Guatemala    14.501    -90.876       3976
# 3                                   Turkey    38.537     34.621       1683
# 4                         USA (Washington)    46.206   -121.490       3742
# ..                                     ...       ...        ...        ...
# 953                    Kamchatka Peninsula    55.862    160.603       3057
# 954                                 Mexico    19.400   -100.250       3500
# 955      Africa (northeastern) and Red Sea    15.050     42.180        191
# 956      Africa (northeastern) and Red Sea    14.020     42.750        624
# 957                       USA (New Mexico)    34.800   -108.000       2550
#
#      ... major_rock_5                              minor_rock_1  \
# 0    ...
# 1    ...
# 2    ...                                  Basalt / Picro-Basalt
# 3    ...
# 4    ...                                                 Dacite
# ..   ...          ...                                       ...
# 953  ...
# 954  ...               Trachyandesite / Basaltic Trachyandesite
# 955  ...
# 956  ...
# 957  ...
#
#                          minor_rock_2 minor_rock_3 minor_rock_4 minor_rock_5  \
# 0
# 1
# 2
# 3
# 4
# ..                                ...          ...          ...          ...
# 953
# 954  Trachybasalt / Tephrite Basanite
# 955
# 956
# 957
#
#     population_within_5_km population_within_10_km population_within_30_km  \
# 0                     3597                    9594                  117805
# 1                        0                       7                     294
# 2                     4329                   60730                 1042836
# 3                   127863                  127863                  218469
# 4                        0                      70                    4019
# ..                     ...                     ...                     ...
# 953                      0                       0                      77
# 954                 231977                  231977                  490440
# 955                      7                       7                       7
# 956                    508                     922                    1075
# 957                     18                      18                     246
#
#     population_within_100_km
# 0                    4071152
# 1                       9092
# 2                    7634778
# 3                    2253483
# 4                     393303
# ..                       ...
# 953                    11184
# 954                  4838069
# 955                   671171
# 956                  1472800
# 957                    54738
#
# [958 rows x 26 columns]

# %%
path = kagglehub.dataset_download("deepcontractor/the-volcanoes-of-earth")

print(os.listdir(path))

file_path = os.path.join(path, "The_Volcanoes_Of_Earth.csv")

volcanoes_of_earth = pd.read_csv(file_path)
volcanoes_of_earth
# Out:
# ['The_Volcanoes_Of_Earth.csv']
#                   Volcano_Name  \
# 0                          Abu
# 1                   Acamarachi
# 2                   Acatenango
# 3              Acigol-Nevsehir
# 4                        Adams
# ...                        ...
# 2657                  Zarechny
# 2658                  Zenikame
# 2659                   Zheltiy
# 2660  Zhupanovskiye Vostriyaky
# 2661                   Zikwala
#
#                                           Volcano_Image       Volcano_Type  \
# 0     https://volcano.si.edu/gallery/photos/GVP-0895...          Shield(s)
# 1     https://volcano.si.edu/gallery/photos/GVP-0688...      Stratovolcano
# 2     https://volcano.si.edu/gallery/photos/GVP-0788...  Stratovolcano(es)
# 3     https://volcano.si.edu/includes/images/noimage...            Caldera
# 4     https://volcano.si.edu/gallery/photos/GVP-0281...      Stratovolcano
# ...                                                 ...                ...
# 2657  https://volcano.si.edu/includes/images/noimage...         Caldera(s)
# 2658  https://volcano.si.edu/includes/images/noimage...          Submarine
# 2659  https://volcano.si.edu/includes/images/noimage...      Stratovolcano
# 2660  https://volcano.si.edu/includes/images/noimage...      Stratovolcano
# 2661  https://volcano.si.edu/includes/images/noimage...      Stratovolcano
#
#             Country                          Region  \
# 0             Japan         Japan, Taiwan, Marianas
# 1             Chile                   South America
# 2         Guatemala      México and Central America
# 3            Turkey  Mediterranean and Western Asia
# 4     United States          Canada and Western USA
# ...             ...                             ...
# 2657         Russia                 Volcanic Region
# 2658          Japan                 Volcanic Region
# 2659         Russia                 Volcanic Region
# 2660         Russia                 Volcanic Region
# 2661       Ethiopia                 Volcanic Region
#
#                                   Subregion epoch_period  \
# 0                                    Honshu     holocene
# 1     Northern Chile, Bolivia and Argentina     holocene
# 2                                 Guatemala     holocene
# 3                                    Turkey     holocene
# 4                          USA (Washington)     holocene
# ...                                     ...          ...
# 2657                    Kamchatka Peninsula  pleistocene
# 2658                               Hokkaido  pleistocene
# 2659                    Kamchatka Peninsula  pleistocene
# 2660                    Kamchatka Peninsula  pleistocene
# 2661      Africa (northeastern) and Red Sea  pleistocene
#
#                     Last_Eruption Summit_and_Elevatiuon  Latitude  Longitude  \
# 0                        6850 BCE        641 m, 2103 ft    34.5°N    131.6°E
# 1     Unknown - Evidence Credible      6023 m, 19760 ft  23.292°S   67.618°W
# 2                         1972 CE      3976 m, 13045 ft  14.501°N   90.876°W
# 3                        2080 BCE       1683 m, 5522 ft  38.537°N   34.621°E
# 4                          950 CE      3742 m, 12277 ft  46.206°N   121.49°W
# ...                           ...                   ...       ...        ...
# 2657                  Pleistocene        760 m, 2493 ft   56.38°N   160.83°E
# 2658                  Pleistocene         -30 m, -98 ft  41.737°N  140.855°E
# 2659                  Pleistocene        792 m, 2598 ft   51.93°N    157.6°E
# 2660                  Pleistocene       1684 m, 5525 ft    53.8°N   159.28°E
# 2661                  Pleistocene       2989 m, 9806 ft    8.53°N    38.85°E
#
#       population_within_5km  population_within_10km  population_within_30km  \
# 0                    3597.0                  9594.0                117805.0
# 1                       0.0                     7.0                   294.0
# 2                    4329.0                 60730.0               1042836.0
# 3                  127863.0                127863.0                218469.0
# 4                       0.0                    70.0                  4019.0
# ...                     ...                     ...                     ...
# 2657                    NaN                     NaN                     NaN
# 2658                    NaN                     NaN                     NaN
# 2659                    NaN                     NaN                     NaN
# 2660                    NaN                     NaN                     NaN
# 2661                    NaN                     NaN                     NaN
#
#       population_within_100km
# 0                   4071152.0
# 1                      9092.0
# 2                   7634778.0
# 3                   2253483.0
# 4                    393303.0
# ...                       ...
# 2657                      NaN
# 2658                      NaN
# 2659                      NaN
# 2660                      NaN
# 2661                      NaN
#
# [2662 rows x 15 columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# #### Eruptions

# %%
# Investigating interetsing columns

eruptions = eruptions[['volcano_name', 'vei', 'start_year',	'latitude', 'longitude']]
eruptions.isna().sum()
# Out:
# volcano_name       0
# vei             2906
# start_year         1
# latitude           0
# longitude          0
# dtype: int64

# %%
# Treating null values

eruptions.dropna(subset=['start_year'], inplace=True)
eruptions['vei'] = eruptions['vei'].fillna(-1)

# %%
eruptions
# Out:
#                  volcano_name  vei  start_year  latitude  longitude
# 0                     Soputan -1.0      2020.0     1.112    124.737
# 1                  San Miguel -1.0      2020.0    13.434    -88.269
# 2      Fournaise, Piton de la -1.0      2020.0   -21.244     55.708
# 3          Rincon de la Vieja -1.0      2020.0    10.830    -85.324
# 4                  Fernandina -1.0      2020.0    -0.370    -91.550
# ...                       ...  ...         ...       ...        ...
# 11172             Nemrut Dagi -1.0     -9950.0    38.654     42.229
# 11173     Craters of the Moon  0.0    -10060.0    43.420   -113.500
# 11174            Igwisi Hills  1.0    -10450.0    -4.889     31.933
# 11175            Quetrupillan  3.0    -10658.0   -39.496    -71.722
# 11176            Quetrupillan  3.0    -11345.0   -39.496    -71.722
#
# [11177 rows x 5 columns]

# %%
# Cleaning start_year column

eruptions["start_year"] = pd.to_numeric(eruptions['start_year'], downcast='integer', errors='coerce')
eruptions.rename(columns={"start_year": "year"}, errors="raise")
# Out:
#                  volcano_name  vei   year  latitude  longitude
# 0                     Soputan -1.0   2020     1.112    124.737
# 1                  San Miguel -1.0   2020    13.434    -88.269
# 2      Fournaise, Piton de la -1.0   2020   -21.244     55.708
# 3          Rincon de la Vieja -1.0   2020    10.830    -85.324
# 4                  Fernandina -1.0   2020    -0.370    -91.550
# ...                       ...  ...    ...       ...        ...
# 11172             Nemrut Dagi -1.0  -9950    38.654     42.229
# 11173     Craters of the Moon  0.0 -10060    43.420   -113.500
# 11174            Igwisi Hills  1.0 -10450    -4.889     31.933
# 11175            Quetrupillan  3.0 -10658   -39.496    -71.722
# 11176            Quetrupillan  3.0 -11345   -39.496    -71.722
#
# [11177 rows x 5 columns]

# %%
eruptions[(eruptions["latitude"] == -21.338) & (eruptions["longitude"] == -175.650)]
# Out:
#      volcano_name  vei  start_year  latitude  longitude
# 3338      Unnamed  0.0        1932   -21.338    -175.65
# 4124      Unnamed  0.0        1907   -21.338    -175.65

# %%
eruptions
# Out:
#                  volcano_name  vei  start_year  latitude  longitude
# 0                     Soputan -1.0        2020     1.112    124.737
# 1                  San Miguel -1.0        2020    13.434    -88.269
# 2      Fournaise, Piton de la -1.0        2020   -21.244     55.708
# 3          Rincon de la Vieja -1.0        2020    10.830    -85.324
# 4                  Fernandina -1.0        2020    -0.370    -91.550
# ...                       ...  ...         ...       ...        ...
# 11172             Nemrut Dagi -1.0       -9950    38.654     42.229
# 11173     Craters of the Moon  0.0      -10060    43.420   -113.500
# 11174            Igwisi Hills  1.0      -10450    -4.889     31.933
# 11175            Quetrupillan  3.0      -10658   -39.496    -71.722
# 11176            Quetrupillan  3.0      -11345   -39.496    -71.722
#
# [11177 rows x 5 columns]

# %% [markdown]
# #### Volcano types

# %%
volcano_types
# Out:
#      volcano_number              volcano_name primary_volcano_type  \
# 0            283001                       Abu            Shield(s)
# 1            355096                Acamarachi        Stratovolcano
# 2            342080                Acatenango    Stratovolcano(es)
# 3            213004           Acigol-Nevsehir              Caldera
# 4            321040                     Adams        Stratovolcano
# ..              ...                       ...                  ...
# 953          300242                    Zimina    Stratovolcano(es)
# 954          341061  Zitacuaro-Valle de Bravo              Caldera
# 955          221020              Zubair Group               Shield
# 956          221021                     Zukur               Shield
# 957          327120              Zuni-Bandera       Volcanic field
#
#     last_eruption_year        country                          region  \
# 0                -6850          Japan         Japan, Taiwan, Marianas
# 1              Unknown          Chile                   South America
# 2                 1972      Guatemala      México and Central America
# 3                -2080         Turkey  Mediterranean and Western Asia
# 4                  950  United States          Canada and Western USA
# ..                 ...            ...                             ...
# 953            Unknown         Russia     Kamchatka and Mainland Asia
# 954              -3050         Mexico      México and Central America
# 955               2013          Yemen              Africa and Red Sea
# 956            Unknown          Yemen              Africa and Red Sea
# 957              -1170  United States          Canada and Western USA
#
#                                  subregion  latitude  longitude  elevation  \
# 0                                   Honshu    34.500    131.600        641
# 1    Northern Chile, Bolivia and Argentina   -23.292    -67.618       6023
# 2                                Guatemala    14.501    -90.876       3976
# 3                                   Turkey    38.537     34.621       1683
# 4                         USA (Washington)    46.206   -121.490       3742
# ..                                     ...       ...        ...        ...
# 953                    Kamchatka Peninsula    55.862    160.603       3057
# 954                                 Mexico    19.400   -100.250       3500
# 955      Africa (northeastern) and Red Sea    15.050     42.180        191
# 956      Africa (northeastern) and Red Sea    14.020     42.750        624
# 957                       USA (New Mexico)    34.800   -108.000       2550
#
#      ... major_rock_5                              minor_rock_1  \
# 0    ...
# 1    ...
# 2    ...                                  Basalt / Picro-Basalt
# 3    ...
# 4    ...                                                 Dacite
# ..   ...          ...                                       ...
# 953  ...
# 954  ...               Trachyandesite / Basaltic Trachyandesite
# 955  ...
# 956  ...
# 957  ...
#
#                          minor_rock_2 minor_rock_3 minor_rock_4 minor_rock_5  \
# 0
# 1
# 2
# 3
# 4
# ..                                ...          ...          ...          ...
# 953
# 954  Trachybasalt / Tephrite Basanite
# 955
# 956
# 957
#
#     population_within_5_km population_within_10_km population_within_30_km  \
# 0                     3597                    9594                  117805
# 1                        0                       7                     294
# 2                     4329                   60730                 1042836
# 3                   127863                  127863                  218469
# 4                        0                      70                    4019
# ..                     ...                     ...                     ...
# 953                      0                       0                      77
# 954                 231977                  231977                  490440
# 955                      7                       7                       7
# 956                    508                     922                    1075
# 957                     18                      18                     246
#
#     population_within_100_km
# 0                    4071152
# 1                       9092
# 2                    7634778
# 3                    2253483
# 4                     393303
# ..                       ...
# 953                    11184
# 954                  4838069
# 955                   671171
# 956                  1472800
# 957                    54738
#
# [958 rows x 26 columns]

# %%
volcano_types = volcano_types[['volcano_name', 'primary_volcano_type', 'elevation']]
volcano_types
# Out:
#                  volcano_name primary_volcano_type  elevation
# 0                         Abu            Shield(s)        641
# 1                  Acamarachi        Stratovolcano       6023
# 2                  Acatenango    Stratovolcano(es)       3976
# 3             Acigol-Nevsehir              Caldera       1683
# 4                       Adams        Stratovolcano       3742
# ..                        ...                  ...        ...
# 953                    Zimina    Stratovolcano(es)       3057
# 954  Zitacuaro-Valle de Bravo              Caldera       3500
# 955              Zubair Group               Shield        191
# 956                     Zukur               Shield        624
# 957              Zuni-Bandera       Volcanic field       2550
#
# [958 rows x 3 columns]

# %%
# Cleaning primary_volcano_type column

volcano_types['primary_volcano_type'] = volcano_types['primary_volcano_type'].replace({
    "Stratovolcano":"Stratovolcano(es)",
    "Stratovolcano?": "Stratovolcano(es)",
    "Pyroclastic cone": "Pyroclastic cone(s)",
    "Shield": "Shield(s) ",
    "Lava dome": "Lava dome(s)",
    "Caldera": "Caldera(s)",
    "Tuff cone": "Tuff cone(s)",
    "Complex": "Complex(es)",
    "Lava cone": "Lava cone(s)",
    "Lava cone(es)": "Lava cone(s)"
})


volcano_types['primary_volcano_type'].value_counts()
# Out:
# /var/folders/yz/shh48k7s5kg3qtp0x9hzjb6c0000gn/T/ipykernel_5123/3315200974.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   volcano_types['primary_volcano_type'] = volcano_types['primary_volcano_type'].replace({
# primary_volcano_type
# Stratovolcano(es)      461
# Shield(s)               85
# Caldera(s)              74
# Pyroclastic cone(s)     74
# Volcanic field          71
# Complex(es)             47
# Shield(s)               33
# Lava dome(s)            29
# Submarine               27
# Fissure vent(s)         12
# Compound                 9
# Maar(s)                  8
# Tuff cone(s)             8
# Pyroclastic shield       7
# Crater rows              5
# Subglacial               5
# Lava cone(s)             3
# Name: count, dtype: int64

# %%
# Merge volcano types and elevations to eruptions dataset

pd.merge(eruptions, volcano_types, on='volcano_name', how='left')
# Out:
#                  volcano_name  vei  start_year  latitude  longitude  \
# 0                     Soputan -1.0      2020.0     1.112    124.737
# 1                  San Miguel -1.0      2020.0    13.434    -88.269
# 2      Fournaise, Piton de la -1.0      2020.0   -21.244     55.708
# 3          Rincon de la Vieja -1.0      2020.0    10.830    -85.324
# 4                  Fernandina -1.0      2020.0    -0.370    -91.550
# ...                       ...  ...         ...       ...        ...
# 11238             Nemrut Dagi -1.0     -9950.0    38.654     42.229
# 11239     Craters of the Moon  0.0    -10060.0    43.420   -113.500
# 11240            Igwisi Hills  1.0    -10450.0    -4.889     31.933
# 11241            Quetrupillan  3.0    -10658.0   -39.496    -71.722
# 11242            Quetrupillan  3.0    -11345.0   -39.496    -71.722
#
#       primary_volcano_type  elevation
# 0        Stratovolcano(es)     1785.0
# 1                      NaN        NaN
# 2               Shield(s)      2632.0
# 3              Complex(es)     1916.0
# 4                      NaN        NaN
# ...                    ...        ...
# 11238    Stratovolcano(es)     2948.0
# 11239  Pyroclastic cone(s)     2005.0
# 11240  Pyroclastic cone(s)     1146.0
# 11241    Stratovolcano(es)     2360.0
# 11242    Stratovolcano(es)     2360.0
#
# [11243 rows x 7 columns]

# %% [markdown]
# #### Volcano Types

# %%
volcanoes_of_earth.columns = [column.lower() for column in volcanoes_of_earth.columns]

# %%
volcanoes_of_earth = volcanoes_of_earth[['volcano_name', 'volcano_type', 'epoch_period']]

# %%
volcanoes_of_earth['volcano_type'].unique()
# Out:
# array(['Shield(s)', 'Stratovolcano', 'Stratovolcano(es)', 'Caldera',
#        'Submarine', 'Shield', 'Volcanic field', 'Fissure vent(s)',
#        'Compound', 'Complex', 'Pyroclastic shield', 'Pyroclastic cone(s)',
#        'Pyroclastic cone', 'Maar', 'Caldera(s)', 'Lava dome(s)',
#        'Lava cone', 'Maar(s)', 'Crater rows', 'Tuff ring(s)',
#        'Tuff cone(s)', 'Explosion crater(s)', 'Complex(es)', 'Lava dome',
#        'Fissure vent', 'Subglacial', 'Cone(s)', 'Tuff cone',
#        'Stratovolcano?', 'Lava cone(s)', 'Lava cone(es)', 'Submarine(es)',
#        'Cone', 'Unknown', 'Lava dome(s) ?', 'Tuya', 'Explosion crater',
#        'Shield?', 'Volcanic remnant', 'Fissure vent(s) ?',
#        'Explosion crater(?)', 'Caldera(?)'], dtype=object)

# %%
# Cleaning primary_volcano_type column

volcanoes_of_earth['volcano_type'] = volcanoes_of_earth['volcano_type'].replace({
    "Stratovolcano":"Stratovolcano(es)",
    "Stratovolcano?": "Stratovolcano(es)",
    "Pyroclastic cone": "Pyroclastic cone(s)",
    "Shield": "Shield(s)",
    "Shield?": "Shield(s)",
    "Lava dome": "Lava dome(s)",
    "Caldera": "Caldera(s)",
    "Caldera(?)": "Caldera(s)",
    "Tuff cone": "Tuff cone(s)",
    "Complex": "Complex(es)",
    "Lava cone": "Lava cone(s)",
    "Lava cone(es)": "Lava cone(s)",
    "Cone": "Cone(s)",
    "Explosion crater": "Explosion crater(s)",
    "Explosion crater(?)": "Explosion crater(s)",
    "Lava dome(s) ?": "Lava dome(s)",
    "Fissure vent(s) ?": "Fissure vent(s)"

})


volcanoes_of_earth['volcano_type'].value_counts()
# Out:
# /var/folders/yz/shh48k7s5kg3qtp0x9hzjb6c0000gn/T/ipykernel_5123/1478020538.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   volcanoes_of_earth['volcano_type'] = volcanoes_of_earth['volcano_type'].replace({
# volcano_type
# Stratovolcano(es)      1102
# Shield(s)               353
# Volcanic field          220
# Pyroclastic cone(s)     208
# Submarine               177
# Caldera(s)              141
# Lava dome(s)            122
# Unknown                  96
# Complex(es)              62
# Fissure vent(s)          29
# Cone(s)                  25
# Compound                 18
# Maar(s)                  18
# Tuff cone(s)             17
# Tuya                     11
# Fissure vent              9
# Lava cone(s)              9
# Maar                      9
# Pyroclastic shield        9
# Explosion crater(s)       8
# Subglacial                6
# Crater rows               6
# Volcanic remnant          3
# Tuff ring(s)              2
# Submarine(es)             2
# Name: count, dtype: int64

# %%
eruptions_and_types = pd.merge(eruptions, volcanoes_of_earth, on='volcano_name', how='left')

# %%
def load_eruption_data():
    # Loading datasets
    eruptions_path = kagglehub.dataset_download("jessemostipak/volcano-eruptions")
    volcanoes_path = kagglehub.dataset_download("deepcontractor/the-volcanoes-of-earth")
    
    eruptions_file = os.path.join(eruptions_path, "eruptions.csv")
    volcanoes_file = os.path.join(volcanoes_path, "The_Volcanoes_Of_Earth.csv")

    eruptions = pd.read_csv(eruptions_file)
    volcanoes_of_earth = pd.read_csv(volcanoes_file)

    # Cleaning eruptions dataset
    eruptions = eruptions[['volcano_name', 'vei', 'start_year',	'latitude', 'longitude']]
    eruptions.dropna(subset=['start_year'], inplace=True)
    eruptions['vei'] = eruptions['vei'].fillna(-1)
    eruptions["start_year"] = pd.to_numeric(eruptions['start_year'], downcast='integer', errors='coerce')
    eruptions.rename(columns={"start_year": "year"}, errors="raise")

    # Cleaning volcanos on earth
    volcanoes_of_earth.columns = [column.lower() for column in volcanoes_of_earth.columns]
    volcanoes_of_earth = volcanoes_of_earth[['volcano_name', 'volcano_type', 'epoch_period']]

    volcanoes_of_earth['volcano_type'] = volcanoes_of_earth['volcano_type'].replace({
        "Stratovolcano":"Stratovolcano(es)",
        "Stratovolcano?": "Stratovolcano(es)",
        "Pyroclastic cone": "Pyroclastic cone(s)",
        "Shield": "Shield(s)",
        "Shield?": "Shield(s)",
        "Lava dome": "Lava dome(s)",
        "Caldera": "Caldera(s)",
        "Caldera(?)": "Caldera(s)",
        "Tuff cone": "Tuff cone(s)",
        "Complex": "Complex(es)",
        "Lava cone": "Lava cone(s)",
        "Lava cone(es)": "Lava cone(s)",
        "Cone": "Cone(s)",
        "Explosion crater": "Explosion crater(s)",
        "Explosion crater(?)": "Explosion crater(s)",
        "Lava dome(s) ?": "Lava dome(s)",
        "Fissure vent(s) ?": "Fissure vent(s)"
    })

    volcanoes_of_earth['epoch_period'] = volcanoes_of_earth['epoch_period'].replace({
        "holocene":"Holoceno",
        "pleistocene": "Pleistocene"
    })

    eruptions_and_types = pd.merge(eruptions, volcanoes_of_earth, on='volcano_name', how='left')

    return eruptions_and_types

# %%
eruptions_and_types = load_eruption_data()
eruptions_and_types
# Out:
#                  volcano_name  vei  start_year  latitude  longitude  \
# 0                     Soputan -1.0        2020     1.112    124.737
# 1                  San Miguel -1.0        2020    13.434    -88.269
# 2      Fournaise, Piton de la -1.0        2020   -21.244     55.708
# 3          Rincon de la Vieja -1.0        2020    10.830    -85.324
# 4                  Fernandina -1.0        2020    -0.370    -91.550
# ...                       ...  ...         ...       ...        ...
# 12227             Nemrut Dagi -1.0       -9950    38.654     42.229
# 12228     Craters of the Moon  0.0      -10060    43.420   -113.500
# 12229            Igwisi Hills  1.0      -10450    -4.889     31.933
# 12230            Quetrupillan  3.0      -10658   -39.496    -71.722
# 12231            Quetrupillan  3.0      -11345   -39.496    -71.722
#
#               volcano_type epoch_period
# 0        Stratovolcano(es)     Holoceno
# 1        Stratovolcano(es)     Holoceno
# 2                Shield(s)     Holoceno
# 3              Complex(es)     Holoceno
# 4                Shield(s)     Holoceno
# ...                    ...          ...
# 12227    Stratovolcano(es)     Holoceno
# 12228  Pyroclastic cone(s)     Holoceno
# 12229  Pyroclastic cone(s)     Holoceno
# 12230    Stratovolcano(es)     Holoceno
# 12231    Stratovolcano(es)     Holoceno
#
# [12232 rows x 7 columns]

# %%
eruptions_and_types["epoch_period"].value_counts()
# Out:
# epoch_period
# Holoceno       11152
# Pleistocene      820
# Name: count, dtype: int64

# %%
eruptions_and_types[eruptions_and_types["volcano_name"] == "Unnamed"]
# Out:
#      volcano_name  vei  start_year  latitude  longitude     volcano_type  \
# 115       Unnamed  0.0      2017.0   -20.852    -175.55  Fissure vent(s)
# 116       Unnamed  0.0      2017.0   -20.852    -175.55        Submarine
# 117       Unnamed  0.0      2017.0   -20.852    -175.55        Submarine
# 118       Unnamed  0.0      2017.0   -20.852    -175.55        Submarine
# 119       Unnamed  0.0      2017.0   -20.852    -175.55        Submarine
# ...           ...  ...         ...       ...        ...              ...
# 7485      Unnamed  0.0      1773.0    20.330     121.75        Submarine
# 7486      Unnamed  0.0      1773.0    20.330     121.75        Submarine
# 7487      Unnamed  0.0      1773.0    20.330     121.75        Submarine
# 7488      Unnamed  0.0      1773.0    20.330     121.75        Submarine
# 7489      Unnamed  0.0      1773.0    20.330     121.75        Submarine
#
#      epoch_period
# 115      Holoceno
# 116      Holoceno
# 117      Holoceno
# 118      Holoceno
# 119      Holoceno
# ...           ...
# 7485  Pleistocene
# 7486  Pleistocene
# 7487  Pleistocene
# 7488  Pleistocene
# 7489  Pleistocene
#
# [960 rows x 7 columns]
