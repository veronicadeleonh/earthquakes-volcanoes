# %%
import kagglehub
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

path = kagglehub.dataset_download("jessemostipak/volcano-eruptions")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/veronica/.cache/kagglehub/datasets/jessemostipak/volcano-eruptions/versions/1

# %%
print(os.listdir(path))

eruptions_path = os.path.join(path, "eruptions.csv")
volcano_path = os.path.join(path, "volcano.csv")

eruptions = pd.read_csv(eruptions_path)
volcano_types = pd.read_csv(volcano_path)

display(eruptions)
display(volcano_types)
# Out:
# ['eruptions.csv', 'sulfur.csv', 'volcano.csv', 'events.csv', 'tree_rings.csv']
#        volcano_number            volcano_name  eruption_number  \
# 0              266030                 Soputan            22354
# 1              343100              San Miguel            22355
# 2              233020  Fournaise, Piton de la            22343
# 3              345020      Rincon de la Vieja            22346
# 4              353010              Fernandina            22347
# ...               ...                     ...              ...
# 11173          324020     Craters of the Moon            21101
# 11174          222161            Igwisi Hills            22141
# 11175          357121            Quetrupillan            22351
# 11176          357121            Quetrupillan            22352
# 11177          390090                Saunders            21099
#
#         eruption_category area_of_activity  vei  start_year  start_month  \
# 0      Confirmed Eruption              NaN  NaN      2020.0          3.0
# 1      Confirmed Eruption              NaN  NaN      2020.0          2.0
# 2      Confirmed Eruption              NaN  NaN      2020.0          2.0
# 3      Confirmed Eruption              NaN  NaN      2020.0          1.0
# 4      Confirmed Eruption              NaN  NaN      2020.0          1.0
# ...                   ...              ...  ...         ...          ...
# 11173  Confirmed Eruption      Sunset cone  0.0    -10060.0          NaN
# 11174  Confirmed Eruption       NE Volcano  1.0    -10450.0          NaN
# 11175  Confirmed Eruption              NaN  3.0    -10658.0          NaN
# 11176  Confirmed Eruption              NaN  3.0    -11345.0          NaN
# 11177  Confirmed Eruption              NaN  0.0         NaN          NaN
#
#        start_day     evidence_method_dating  end_year  end_month  end_day  \
# 0           23.0    Historical Observations    2020.0        4.0      2.0
# 1           22.0    Historical Observations    2020.0        2.0     22.0
# 2           10.0    Historical Observations    2020.0        4.0      6.0
# 3           31.0    Historical Observations    2020.0        4.0     17.0
# 4           12.0    Historical Observations    2020.0        1.0     12.0
# ...          ...                        ...       ...        ...      ...
# 11173        NaN  Radiocarbon (uncorrected)       NaN        NaN      NaN
# 11174        NaN           Surface Exposure       NaN        NaN      NaN
# 11175        NaN    Radiocarbon (corrected)       NaN        NaN      NaN
# 11176        NaN    Radiocarbon (corrected)       NaN        NaN      NaN
# 11177        NaN                        NaN       NaN        NaN      NaN
#
#        latitude  longitude
# 0         1.112    124.737
# 1        13.434    -88.269
# 2       -21.244     55.708
# 3        10.830    -85.324
# 4        -0.370    -91.550
# ...         ...        ...
# 11173    43.420   -113.500
# 11174    -4.889     31.933
# 11175   -39.496    -71.722
# 11176   -39.496    -71.722
# 11177   -57.800    -26.483
#
# [11178 rows x 15 columns]
#      volcano_number              volcano_name primary_volcano_type  \
# 0            283001                       Abu            Shield(s)
# 1            355096                Acamarachi        Stratovolcano
# 2            342080                Acatenango    Stratovolcano(es)
# 3            213004           Acigol-Nevsehir              Caldera
# 4            321040                     Adams        Stratovolcano
# ..              ...                       ...                  ...
# 953          300242                    Zimina    Stratovolcano(es)
# 954          341061  Zitacuaro-Valle de Bravo              Caldera
# 955          221020              Zubair Group               Shield
# 956          221021                     Zukur               Shield
# 957          327120              Zuni-Bandera       Volcanic field
#
#     last_eruption_year        country                          region  \
# 0                -6850          Japan         Japan, Taiwan, Marianas
# 1              Unknown          Chile                   South America
# 2                 1972      Guatemala      México and Central America
# 3                -2080         Turkey  Mediterranean and Western Asia
# 4                  950  United States          Canada and Western USA
# ..                 ...            ...                             ...
# 953            Unknown         Russia     Kamchatka and Mainland Asia
# 954              -3050         Mexico      México and Central America
# 955               2013          Yemen              Africa and Red Sea
# 956            Unknown          Yemen              Africa and Red Sea
# 957              -1170  United States          Canada and Western USA
#
#                                  subregion  latitude  longitude  elevation  \
# 0                                   Honshu    34.500    131.600        641
# 1    Northern Chile, Bolivia and Argentina   -23.292    -67.618       6023
# 2                                Guatemala    14.501    -90.876       3976
# 3                                   Turkey    38.537     34.621       1683
# 4                         USA (Washington)    46.206   -121.490       3742
# ..                                     ...       ...        ...        ...
# 953                    Kamchatka Peninsula    55.862    160.603       3057
# 954                                 Mexico    19.400   -100.250       3500
# 955      Africa (northeastern) and Red Sea    15.050     42.180        191
# 956      Africa (northeastern) and Red Sea    14.020     42.750        624
# 957                       USA (New Mexico)    34.800   -108.000       2550
#
#      ... major_rock_5                              minor_rock_1  \
# 0    ...
# 1    ...
# 2    ...                                  Basalt / Picro-Basalt
# 3    ...
# 4    ...                                                 Dacite
# ..   ...          ...                                       ...
# 953  ...
# 954  ...               Trachyandesite / Basaltic Trachyandesite
# 955  ...
# 956  ...
# 957  ...
#
#                          minor_rock_2 minor_rock_3 minor_rock_4 minor_rock_5  \
# 0
# 1
# 2
# 3
# 4
# ..                                ...          ...          ...          ...
# 953
# 954  Trachybasalt / Tephrite Basanite
# 955
# 956
# 957
#
#     population_within_5_km population_within_10_km population_within_30_km  \
# 0                     3597                    9594                  117805
# 1                        0                       7                     294
# 2                     4329                   60730                 1042836
# 3                   127863                  127863                  218469
# 4                        0                      70                    4019
# ..                     ...                     ...                     ...
# 953                      0                       0                      77
# 954                 231977                  231977                  490440
# 955                      7                       7                       7
# 956                    508                     922                    1075
# 957                     18                      18                     246
#
#     population_within_100_km
# 0                    4071152
# 1                       9092
# 2                    7634778
# 3                    2253483
# 4                     393303
# ..                       ...
# 953                    11184
# 954                  4838069
# 955                   671171
# 956                  1472800
# 957                    54738
#
# [958 rows x 26 columns]

# %%
path = kagglehub.dataset_download("deepcontractor/the-volcanoes-of-earth")

print(os.listdir(path))

file_path = os.path.join(path, "The_Volcanoes_Of_Earth.csv")

volcanoes_of_earth = pd.read_csv(file_path)
volcanoes_of_earth
# Out:
# ['The_Volcanoes_Of_Earth.csv']
#                   Volcano_Name  \
# 0                          Abu
# 1                   Acamarachi
# 2                   Acatenango
# 3              Acigol-Nevsehir
# 4                        Adams
# ...                        ...
# 2657                  Zarechny
# 2658                  Zenikame
# 2659                   Zheltiy
# 2660  Zhupanovskiye Vostriyaky
# 2661                   Zikwala
#
#                                           Volcano_Image       Volcano_Type  \
# 0     https://volcano.si.edu/gallery/photos/GVP-0895...          Shield(s)
# 1     https://volcano.si.edu/gallery/photos/GVP-0688...      Stratovolcano
# 2     https://volcano.si.edu/gallery/photos/GVP-0788...  Stratovolcano(es)
# 3     https://volcano.si.edu/includes/images/noimage...            Caldera
# 4     https://volcano.si.edu/gallery/photos/GVP-0281...      Stratovolcano
# ...                                                 ...                ...
# 2657  https://volcano.si.edu/includes/images/noimage...         Caldera(s)
# 2658  https://volcano.si.edu/includes/images/noimage...          Submarine
# 2659  https://volcano.si.edu/includes/images/noimage...      Stratovolcano
# 2660  https://volcano.si.edu/includes/images/noimage...      Stratovolcano
# 2661  https://volcano.si.edu/includes/images/noimage...      Stratovolcano
#
#             Country                          Region  \
# 0             Japan         Japan, Taiwan, Marianas
# 1             Chile                   South America
# 2         Guatemala      México and Central America
# 3            Turkey  Mediterranean and Western Asia
# 4     United States          Canada and Western USA
# ...             ...                             ...
# 2657         Russia                 Volcanic Region
# 2658          Japan                 Volcanic Region
# 2659         Russia                 Volcanic Region
# 2660         Russia                 Volcanic Region
# 2661       Ethiopia                 Volcanic Region
#
#                                   Subregion epoch_period  \
# 0                                    Honshu     holocene
# 1     Northern Chile, Bolivia and Argentina     holocene
# 2                                 Guatemala     holocene
# 3                                    Turkey     holocene
# 4                          USA (Washington)     holocene
# ...                                     ...          ...
# 2657                    Kamchatka Peninsula  pleistocene
# 2658                               Hokkaido  pleistocene
# 2659                    Kamchatka Peninsula  pleistocene
# 2660                    Kamchatka Peninsula  pleistocene
# 2661      Africa (northeastern) and Red Sea  pleistocene
#
#                     Last_Eruption Summit_and_Elevatiuon  Latitude  Longitude  \
# 0                        6850 BCE        641 m, 2103 ft    34.5°N    131.6°E
# 1     Unknown - Evidence Credible      6023 m, 19760 ft  23.292°S   67.618°W
# 2                         1972 CE      3976 m, 13045 ft  14.501°N   90.876°W
# 3                        2080 BCE       1683 m, 5522 ft  38.537°N   34.621°E
# 4                          950 CE      3742 m, 12277 ft  46.206°N   121.49°W
# ...                           ...                   ...       ...        ...
# 2657                  Pleistocene        760 m, 2493 ft   56.38°N   160.83°E
# 2658                  Pleistocene         -30 m, -98 ft  41.737°N  140.855°E
# 2659                  Pleistocene        792 m, 2598 ft   51.93°N    157.6°E
# 2660                  Pleistocene       1684 m, 5525 ft    53.8°N   159.28°E
# 2661                  Pleistocene       2989 m, 9806 ft    8.53°N    38.85°E
#
#       population_within_5km  population_within_10km  population_within_30km  \
# 0                    3597.0                  9594.0                117805.0
# 1                       0.0                     7.0                   294.0
# 2                    4329.0                 60730.0               1042836.0
# 3                  127863.0                127863.0                218469.0
# 4                       0.0                    70.0                  4019.0
# ...                     ...                     ...                     ...
# 2657                    NaN                     NaN                     NaN
# 2658                    NaN                     NaN                     NaN
# 2659                    NaN                     NaN                     NaN
# 2660                    NaN                     NaN                     NaN
# 2661                    NaN                     NaN                     NaN
#
#       population_within_100km
# 0                   4071152.0
# 1                      9092.0
# 2                   7634778.0
# 3                   2253483.0
# 4                    393303.0
# ...                       ...
# 2657                      NaN
# 2658                      NaN
# 2659                      NaN
# 2660                      NaN
# 2661                      NaN
#
# [2662 rows x 15 columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# #### Eruptions

# %%
# Investigating interetsing columns

eruptions = eruptions[['volcano_name', 'vei', 'start_year',	'latitude', 'longitude']]
eruptions.isna().sum()
# Out:
# volcano_name       0
# vei             2906
# start_year         1
# latitude           0
# longitude          0
# dtype: int64

# %%
# Treating null values

eruptions.dropna(subset=['start_year'], inplace=True)
eruptions['vei'] = eruptions['vei'].fillna(-1)

# %%
eruptions
# Out:
#                  volcano_name  vei  start_year  latitude  longitude
# 0                     Soputan -1.0      2020.0     1.112    124.737
# 1                  San Miguel -1.0      2020.0    13.434    -88.269
# 2      Fournaise, Piton de la -1.0      2020.0   -21.244     55.708
# 3          Rincon de la Vieja -1.0      2020.0    10.830    -85.324
# 4                  Fernandina -1.0      2020.0    -0.370    -91.550
# ...                       ...  ...         ...       ...        ...
# 11172             Nemrut Dagi -1.0     -9950.0    38.654     42.229
# 11173     Craters of the Moon  0.0    -10060.0    43.420   -113.500
# 11174            Igwisi Hills  1.0    -10450.0    -4.889     31.933
# 11175            Quetrupillan  3.0    -10658.0   -39.496    -71.722
# 11176            Quetrupillan  3.0    -11345.0   -39.496    -71.722
#
# [11177 rows x 5 columns]

# %%
# Cleaning start_year column

eruptions["start_year"] = pd.to_numeric(eruptions['start_year'], downcast='integer', errors='coerce')
eruptions.rename(columns={"start_year": "year"}, errors="raise")
# Out:
#                  volcano_name  vei   year  latitude  longitude
# 0                     Soputan -1.0   2020     1.112    124.737
# 1                  San Miguel -1.0   2020    13.434    -88.269
# 2      Fournaise, Piton de la -1.0   2020   -21.244     55.708
# 3          Rincon de la Vieja -1.0   2020    10.830    -85.324
# 4                  Fernandina -1.0   2020    -0.370    -91.550
# ...                       ...  ...    ...       ...        ...
# 11172             Nemrut Dagi -1.0  -9950    38.654     42.229
# 11173     Craters of the Moon  0.0 -10060    43.420   -113.500
# 11174            Igwisi Hills  1.0 -10450    -4.889     31.933
# 11175            Quetrupillan  3.0 -10658   -39.496    -71.722
# 11176            Quetrupillan  3.0 -11345   -39.496    -71.722
#
# [11177 rows x 5 columns]

# %%
eruptions[(eruptions["latitude"] == -21.338) & (eruptions["longitude"] == -175.650)]
# Out:
#      volcano_name  vei  start_year  latitude  longitude
# 3338      Unnamed  0.0        1932   -21.338    -175.65
# 4124      Unnamed  0.0        1907   -21.338    -175.65

# %%
# Manually adding volanic names based on latitude and logitude to unnamed ones

volcano_names = {
    (-20.852, -175.550): 'Hunga Tonga-Hunga Ha\'apai',
    (-18.325, -174.365): 'Late Island',
    (46.470, 151.280): 'Chirinkotan',
    (45.022, 147.019): 'Ekarma',
    (-21.338, -175.650): 'Kao',
    (21.830, 121.180): 'Green Island',
    (20.330, 121.750): 'Babuyan Claro',
    (24.132, 121.926): 'Qixing Mountain'
}

# Update the volcano names
eruptions['volcano_name'] = eruptions.apply(
    lambda row: volcano_names.get((row['latitude'], row['longitude']), row['volcano_name']),
    axis=1
)

# %% [markdown]
# #### Volcano types

# %%
volcano_types
# Out:
#      volcano_number              volcano_name primary_volcano_type  \
# 0            283001                       Abu            Shield(s)
# 1            355096                Acamarachi        Stratovolcano
# 2            342080                Acatenango    Stratovolcano(es)
# 3            213004           Acigol-Nevsehir              Caldera
# 4            321040                     Adams        Stratovolcano
# ..              ...                       ...                  ...
# 953          300242                    Zimina    Stratovolcano(es)
# 954          341061  Zitacuaro-Valle de Bravo              Caldera
# 955          221020              Zubair Group               Shield
# 956          221021                     Zukur               Shield
# 957          327120              Zuni-Bandera       Volcanic field
#
#     last_eruption_year        country                          region  \
# 0                -6850          Japan         Japan, Taiwan, Marianas
# 1              Unknown          Chile                   South America
# 2                 1972      Guatemala      México and Central America
# 3                -2080         Turkey  Mediterranean and Western Asia
# 4                  950  United States          Canada and Western USA
# ..                 ...            ...                             ...
# 953            Unknown         Russia     Kamchatka and Mainland Asia
# 954              -3050         Mexico      México and Central America
# 955               2013          Yemen              Africa and Red Sea
# 956            Unknown          Yemen              Africa and Red Sea
# 957              -1170  United States          Canada and Western USA
#
#                                  subregion  latitude  longitude  elevation  \
# 0                                   Honshu    34.500    131.600        641
# 1    Northern Chile, Bolivia and Argentina   -23.292    -67.618       6023
# 2                                Guatemala    14.501    -90.876       3976
# 3                                   Turkey    38.537     34.621       1683
# 4                         USA (Washington)    46.206   -121.490       3742
# ..                                     ...       ...        ...        ...
# 953                    Kamchatka Peninsula    55.862    160.603       3057
# 954                                 Mexico    19.400   -100.250       3500
# 955      Africa (northeastern) and Red Sea    15.050     42.180        191
# 956      Africa (northeastern) and Red Sea    14.020     42.750        624
# 957                       USA (New Mexico)    34.800   -108.000       2550
#
#      ... major_rock_5                              minor_rock_1  \
# 0    ...
# 1    ...
# 2    ...                                  Basalt / Picro-Basalt
# 3    ...
# 4    ...                                                 Dacite
# ..   ...          ...                                       ...
# 953  ...
# 954  ...               Trachyandesite / Basaltic Trachyandesite
# 955  ...
# 956  ...
# 957  ...
#
#                          minor_rock_2 minor_rock_3 minor_rock_4 minor_rock_5  \
# 0
# 1
# 2
# 3
# 4
# ..                                ...          ...          ...          ...
# 953
# 954  Trachybasalt / Tephrite Basanite
# 955
# 956
# 957
#
#     population_within_5_km population_within_10_km population_within_30_km  \
# 0                     3597                    9594                  117805
# 1                        0                       7                     294
# 2                     4329                   60730                 1042836
# 3                   127863                  127863                  218469
# 4                        0                      70                    4019
# ..                     ...                     ...                     ...
# 953                      0                       0                      77
# 954                 231977                  231977                  490440
# 955                      7                       7                       7
# 956                    508                     922                    1075
# 957                     18                      18                     246
#
#     population_within_100_km
# 0                    4071152
# 1                       9092
# 2                    7634778
# 3                    2253483
# 4                     393303
# ..                       ...
# 953                    11184
# 954                  4838069
# 955                   671171
# 956                  1472800
# 957                    54738
#
# [958 rows x 26 columns]

# %%
volcano_types = volcano_types[['volcano_name', 'primary_volcano_type', 'elevation']]
volcano_types
# Out:
#                  volcano_name primary_volcano_type  elevation
# 0                         Abu            Shield(s)        641
# 1                  Acamarachi        Stratovolcano       6023
# 2                  Acatenango    Stratovolcano(es)       3976
# 3             Acigol-Nevsehir              Caldera       1683
# 4                       Adams        Stratovolcano       3742
# ..                        ...                  ...        ...
# 953                    Zimina    Stratovolcano(es)       3057
# 954  Zitacuaro-Valle de Bravo              Caldera       3500
# 955              Zubair Group               Shield        191
# 956                     Zukur               Shield        624
# 957              Zuni-Bandera       Volcanic field       2550
#
# [958 rows x 3 columns]

# %%
# Cleaning primary_volcano_type column

volcano_types['primary_volcano_type'] = volcano_types['primary_volcano_type'].replace({
    "Stratovolcano":"Stratovolcano(es)",
    "Stratovolcano?": "Stratovolcano(es)",
    "Pyroclastic cone": "Pyroclastic cone(s)",
    "Shield": "Shield(s) ",
    "Lava dome": "Lava dome(s)",
    "Caldera": "Caldera(s)",
    "Tuff cone": "Tuff cone(s)",
    "Complex": "Complex(es)",
    "Lava cone": "Lava cone(s)",
    "Lava cone(es)": "Lava cone(s)"
})


volcano_types['primary_volcano_type'].value_counts()
# Out:
# /var/folders/yz/shh48k7s5kg3qtp0x9hzjb6c0000gn/T/ipykernel_13058/3315200974.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   volcano_types['primary_volcano_type'] = volcano_types['primary_volcano_type'].replace({
# primary_volcano_type
# Stratovolcano(es)      461
# Shield(s)               85
# Caldera(s)              74
# Pyroclastic cone(s)     74
# Volcanic field          71
# Complex(es)             47
# Shield(s)               33
# Lava dome(s)            29
# Submarine               27
# Fissure vent(s)         12
# Compound                 9
# Maar(s)                  8
# Tuff cone(s)             8
# Pyroclastic shield       7
# Crater rows              5
# Subglacial               5
# Lava cone(s)             3
# Name: count, dtype: int64

# %%
# Merge volcano types and elevations to eruptions dataset

pd.merge(eruptions, volcano_types, on='volcano_name', how='left')
# Out:
#                  volcano_name  vei  start_year  latitude  longitude  \
# 0                     Soputan -1.0        2020     1.112    124.737
# 1                  San Miguel -1.0        2020    13.434    -88.269
# 2      Fournaise, Piton de la -1.0        2020   -21.244     55.708
# 3          Rincon de la Vieja -1.0        2020    10.830    -85.324
# 4                  Fernandina -1.0        2020    -0.370    -91.550
# ...                       ...  ...         ...       ...        ...
# 11238             Nemrut Dagi -1.0       -9950    38.654     42.229
# 11239     Craters of the Moon  0.0      -10060    43.420   -113.500
# 11240            Igwisi Hills  1.0      -10450    -4.889     31.933
# 11241            Quetrupillan  3.0      -10658   -39.496    -71.722
# 11242            Quetrupillan  3.0      -11345   -39.496    -71.722
#
#       primary_volcano_type  elevation
# 0        Stratovolcano(es)     1785.0
# 1                      NaN        NaN
# 2               Shield(s)      2632.0
# 3              Complex(es)     1916.0
# 4                      NaN        NaN
# ...                    ...        ...
# 11238    Stratovolcano(es)     2948.0
# 11239  Pyroclastic cone(s)     2005.0
# 11240  Pyroclastic cone(s)     1146.0
# 11241    Stratovolcano(es)     2360.0
# 11242    Stratovolcano(es)     2360.0
#
# [11243 rows x 7 columns]

# %% [markdown]
# #### Volcano Types

# %%
volcanoes_of_earth.columns = [column.lower() for column in volcanoes_of_earth.columns]

# %%
volcanoes_of_earth = volcanoes_of_earth[['volcano_name', 'volcano_type', 'epoch_period', 'summit_and_elevatiuon']]

# %%
# Cleaning primary_volcano_type column

volcanoes_of_earth['volcano_type'] = volcanoes_of_earth['volcano_type'].replace({
    "Stratovolcano":"Stratovolcano(es)",
    "Stratovolcano?": "Stratovolcano(es)",
    "Pyroclastic cone": "Pyroclastic cone(s)",
    "Shield": "Shield(s)",
    "Shield?": "Shield(s)",
    "Lava dome": "Lava dome(s)",
    "Caldera": "Caldera(s)",
    "Caldera(?)": "Caldera(s)",
    "Tuff cone": "Tuff cone(s)",
    "Complex": "Complex(es)",
    "Lava cone": "Lava cone(s)",
    "Lava cone(es)": "Lava cone(s)",
    "Cone": "Cone(s)",
    "Explosion crater": "Explosion crater(s)",
    "Explosion crater(?)": "Explosion crater(s)",
    "Lava dome(s) ?": "Lava dome(s)",
    "Fissure vent(s) ?": "Fissure vent(s)"

})


volcanoes_of_earth['volcano_type'].value_counts()
# Out:
# /var/folders/yz/shh48k7s5kg3qtp0x9hzjb6c0000gn/T/ipykernel_13058/1478020538.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   volcanoes_of_earth['volcano_type'] = volcanoes_of_earth['volcano_type'].replace({
# volcano_type
# Stratovolcano(es)      1102
# Shield(s)               353
# Volcanic field          220
# Pyroclastic cone(s)     208
# Submarine               177
# Caldera(s)              141
# Lava dome(s)            122
# Unknown                  96
# Complex(es)              62
# Fissure vent(s)          29
# Cone(s)                  25
# Compound                 18
# Maar(s)                  18
# Tuff cone(s)             17
# Tuya                     11
# Fissure vent              9
# Lava cone(s)              9
# Maar                      9
# Pyroclastic shield        9
# Explosion crater(s)       8
# Subglacial                6
# Crater rows               6
# Volcanic remnant          3
# Tuff ring(s)              2
# Submarine(es)             2
# Name: count, dtype: int64

# %%
volcanoes_of_earth['epoch_period'] = volcanoes_of_earth['epoch_period'].replace({
        "holocene":"Holoceno",
        "pleistocene": "Pleistocene"
    })
# Out:
# /var/folders/yz/shh48k7s5kg3qtp0x9hzjb6c0000gn/T/ipykernel_13058/2319368179.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   volcanoes_of_earth['epoch_period'] = volcanoes_of_earth['epoch_period'].replace({

# %%
volcanoes_of_earth.rename(columns={'summit_and_elevatiuon':'elevation'}, inplace=True)
volcanoes_of_earth
# Out:
# /var/folders/yz/shh48k7s5kg3qtp0x9hzjb6c0000gn/T/ipykernel_13058/3500446352.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   volcanoes_of_earth.rename(columns={'summit_and_elevatiuon':'elevation'}, inplace=True)
#                   volcano_name       volcano_type epoch_period  \
# 0                          Abu          Shield(s)     Holoceno
# 1                   Acamarachi  Stratovolcano(es)     Holoceno
# 2                   Acatenango  Stratovolcano(es)     Holoceno
# 3              Acigol-Nevsehir         Caldera(s)     Holoceno
# 4                        Adams  Stratovolcano(es)     Holoceno
# ...                        ...                ...          ...
# 2657                  Zarechny         Caldera(s)  Pleistocene
# 2658                  Zenikame          Submarine  Pleistocene
# 2659                   Zheltiy  Stratovolcano(es)  Pleistocene
# 2660  Zhupanovskiye Vostriyaky  Stratovolcano(es)  Pleistocene
# 2661                   Zikwala  Stratovolcano(es)  Pleistocene
#
#              elevation
# 0       641 m, 2103 ft
# 1     6023 m, 19760 ft
# 2     3976 m, 13045 ft
# 3      1683 m, 5522 ft
# 4     3742 m, 12277 ft
# ...                ...
# 2657    760 m, 2493 ft
# 2658     -30 m, -98 ft
# 2659    792 m, 2598 ft
# 2660   1684 m, 5525 ft
# 2661   2989 m, 9806 ft
#
# [2662 rows x 4 columns]

# %%
volcanoes_of_earth[volcanoes_of_earth.isnull().any(axis=1)]
# Out:
#      volcano_name       volcano_type epoch_period elevation
# 1343          Aak  Stratovolcano(es)  Pleistocene       NaN

# %%
volcanoes_of_earth.loc[1343, 'elevation'] = 2319
volcanoes_of_earth[volcanoes_of_earth['volcano_name'] == 'Aak']
# Out:
#      volcano_name       volcano_type epoch_period elevation
# 1343          Aak  Stratovolcano(es)  Pleistocene      2319

# %%
volcanoes_of_earth['elevation'].value_counts().reset_index()
# Out:
#              elevation  count
# 0           Unknown,      125
# 1       600 m, 1969 ft     12
# 2       500 m, 1640 ft      9
# 3      1000 m, 3281 ft      9
# 4      1100 m, 3609 ft      8
# ...                ...    ...
# 1832    940 m, 3084 ft      1
# 1833  3977 m, 13048 ft      1
# 1834   1088 m, 3570 ft      1
# 1835   -300 m, -984 ft      1
# 1836   2989 m, 9806 ft      1
#
# [1837 rows x 2 columns]

# %%
for index, value in volcanoes_of_earth['elevation'].items():
    if isinstance(value, str) and "Unknown," in value:
        volcanoes_of_earth.at[index, 'elevation'] = -99999
    elif isinstance(value, str): 
        volcanoes_of_earth.at[index, 'elevation'] = int(value.split()[0])
    elif isinstance(value, (int, float)):
        volcanoes_of_earth.at[index, 'elevation'] = int(value)
    else:
        volcanoes_of_earth.at[index, 'elevation'] = -99999


volcanoes_of_earth['elevation'].value_counts().reset_index()
# Out:
#       elevation  count
# 0        -99999    125
# 1           600     12
# 2           500      9
# 3          1000      9
# 4          1100      8
# ...         ...    ...
# 1832        940      1
# 1833       3977      1
# 1834       1088      1
# 1835       -300      1
# 1836       2989      1
#
# [1837 rows x 2 columns]

# %%
eruptions_and_types = pd.merge(eruptions, volcanoes_of_earth, on='volcano_name', how='left')
eruptions_and_types.drop_duplicates()
# Out:
#                  volcano_name  vei  start_year  latitude  longitude  \
# 0                     Soputan -1.0        2020     1.112    124.737
# 1                  San Miguel -1.0        2020    13.434    -88.269
# 2      Fournaise, Piton de la -1.0        2020   -21.244     55.708
# 3          Rincon de la Vieja -1.0        2020    10.830    -85.324
# 4                  Fernandina -1.0        2020    -0.370    -91.550
# ...                       ...  ...         ...       ...        ...
# 11282             Nemrut Dagi -1.0       -9950    38.654     42.229
# 11283     Craters of the Moon  0.0      -10060    43.420   -113.500
# 11284            Igwisi Hills  1.0      -10450    -4.889     31.933
# 11285            Quetrupillan  3.0      -10658   -39.496    -71.722
# 11286            Quetrupillan  3.0      -11345   -39.496    -71.722
#
#               volcano_type epoch_period elevation
# 0        Stratovolcano(es)     Holoceno      1785
# 1        Stratovolcano(es)     Holoceno      2130
# 2                Shield(s)     Holoceno      2632
# 3              Complex(es)     Holoceno      1916
# 4                Shield(s)     Holoceno      1476
# ...                    ...          ...       ...
# 11282    Stratovolcano(es)     Holoceno      2948
# 11283  Pyroclastic cone(s)     Holoceno      2005
# 11284  Pyroclastic cone(s)     Holoceno      1146
# 11285    Stratovolcano(es)     Holoceno      2360
# 11286    Stratovolcano(es)     Holoceno      2360
#
# [10990 rows x 8 columns]

# %%
def load_eruption_data():
    # Loading datasets
    eruptions_path = kagglehub.dataset_download("jessemostipak/volcano-eruptions")
    volcanoes_path = kagglehub.dataset_download("deepcontractor/the-volcanoes-of-earth")
    
    eruptions_file = os.path.join(eruptions_path, "eruptions.csv")
    volcanoes_file = os.path.join(volcanoes_path, "The_Volcanoes_Of_Earth.csv")

    eruptions = pd.read_csv(eruptions_file)
    volcanoes_of_earth = pd.read_csv(volcanoes_file)

    # Cleaning eruptions dataset
    eruptions = eruptions[['volcano_name', 'vei', 'start_year',	'latitude', 'longitude']]
    eruptions.dropna(subset=['start_year'], inplace=True)
    eruptions['vei'] = eruptions['vei'].fillna(-1)
    eruptions["start_year"] = pd.to_numeric(eruptions['start_year'], downcast='integer', errors='coerce')
    eruptions.rename(columns={"start_year": "year"}, errors="raise", inplace=True)

    # Cleaning volcano names
    volcano_names = {
    (-20.852, -175.550): 'Hunga Tonga-Hunga Ha\'apai',
    (-18.325, -174.365): 'Late Island',
    (46.470, 151.280): 'Chirinkotan',
    (45.022, 147.019): 'Ekarma',
    (-21.338, -175.650): 'Kao',
    (21.830, 121.180): 'Green Island',
    (20.330, 121.750): 'Babuyan Claro',
    (24.132, 121.926): 'Qixing Mountain'
    }

    # Update the volcano names
    eruptions['volcano_name'] = eruptions.apply(
        lambda row: volcano_names.get((row['latitude'], row['longitude']), row['volcano_name']),
        axis=1
    )

    # Cleaning volcanos on earth
    volcanoes_of_earth.columns = [column.lower() for column in volcanoes_of_earth.columns]
    volcanoes_of_earth = volcanoes_of_earth[['volcano_name', 'volcano_type', 'epoch_period', 'summit_and_elevatiuon']]

    volcanoes_of_earth['volcano_type'] = volcanoes_of_earth['volcano_type'].replace({
        "Stratovolcano":"Stratovolcano(es)",
        "Stratovolcano?": "Stratovolcano(es)",
        "Pyroclastic cone": "Pyroclastic cone(s)",
        "Shield": "Shield(s)",
        "Shield?": "Shield(s)",
        "Lava dome": "Lava dome(s)",
        "Caldera": "Caldera(s)",
        "Caldera(?)": "Caldera(s)",
        "Tuff cone": "Tuff cone(s)",
        "Complex": "Complex(es)",
        "Lava cone": "Lava cone(s)",
        "Lava cone(es)": "Lava cone(s)",
        "Cone": "Cone(s)",
        "Explosion crater": "Explosion crater(s)",
        "Explosion crater(?)": "Explosion crater(s)",
        "Lava dome(s) ?": "Lava dome(s)",
        "Fissure vent(s) ?": "Fissure vent(s)"
    })

    volcanoes_of_earth['epoch_period'] = volcanoes_of_earth['epoch_period'].replace({
        "holocene":"Holoceno",
        "pleistocene": "Pleistocene"
    })

    # Renaming the column to "elevation"
    volcanoes_of_earth.rename(columns={'summit_and_elevatiuon':'elevation'}, inplace=True)
    # Replacing manually the value for Aak volcano
    volcanoes_of_earth.loc[1343, 'elevation'] = 2319
    
    # Process the elevation column
    for index, value in volcanoes_of_earth['elevation'].items():
        if isinstance(value, str) and "Unknown," in value:
            volcanoes_of_earth.at[index, 'elevation'] = -99999
        elif isinstance(value, str): 
            volcanoes_of_earth.at[index, 'elevation'] = int(value.split()[0])
        elif isinstance(value, (int, float)):
            volcanoes_of_earth.at[index, 'elevation'] = int(value)
        else:
            volcanoes_of_earth.at[index, 'elevation'] = -99999

    eruptions_and_types = pd.merge(eruptions, volcanoes_of_earth, on='volcano_name', how='left')

    return eruptions_and_types

# %%
eruptions_and_types = load_eruption_data()
eruptions_and_types
# Out:
#                  volcano_name  vei   year  latitude  longitude  \
# 0                     Soputan -1.0   2020     1.112    124.737
# 1                  San Miguel -1.0   2020    13.434    -88.269
# 2      Fournaise, Piton de la -1.0   2020   -21.244     55.708
# 3          Rincon de la Vieja -1.0   2020    10.830    -85.324
# 4                  Fernandina -1.0   2020    -0.370    -91.550
# ...                       ...  ...    ...       ...        ...
# 11282             Nemrut Dagi -1.0  -9950    38.654     42.229
# 11283     Craters of the Moon  0.0 -10060    43.420   -113.500
# 11284            Igwisi Hills  1.0 -10450    -4.889     31.933
# 11285            Quetrupillan  3.0 -10658   -39.496    -71.722
# 11286            Quetrupillan  3.0 -11345   -39.496    -71.722
#
#               volcano_type epoch_period elevation
# 0        Stratovolcano(es)     Holoceno      1785
# 1        Stratovolcano(es)     Holoceno      2130
# 2                Shield(s)     Holoceno      2632
# 3              Complex(es)     Holoceno      1916
# 4                Shield(s)     Holoceno      1476
# ...                    ...          ...       ...
# 11282    Stratovolcano(es)     Holoceno      2948
# 11283  Pyroclastic cone(s)     Holoceno      2005
# 11284  Pyroclastic cone(s)     Holoceno      1146
# 11285    Stratovolcano(es)     Holoceno      2360
# 11286    Stratovolcano(es)     Holoceno      2360
#
# [11287 rows x 8 columns]

# %% [markdown]
# ### EDA

# %%
#First recorded eruption year
eruptions_and_types.groupby('volcano_name')['year'].transform('min')
# Out:
# 0         1450
# 1         1510
# 2        -2800
# 3        -1820
# 4          950
#          ...
# 11282    -9950
# 11283   -10060
# 11284   -10450
# 11285   -11345
# 11286   -11345
# Name: year, Length: 11287, dtype: int16

# %%
def load_top_10_eruptions_count(eruptions_and_types):
    eruptions_and_types['first_eruption_year'] = eruptions_and_types.groupby('volcano_name')['year'].transform('min')
    eruptions_and_types['last_eruption_year'] = eruptions_and_types.groupby('volcano_name')['year'].transform('max')

    # Group by volcano_name, volcano_type and count eruptions
    top_10_eruptions_count = (
        eruptions_and_types.groupby(['volcano_name', 'volcano_type', 'first_eruption_year', 'last_eruption_year'])
        .size()
        .reset_index(name='eruption_count')
        .sort_values(by='eruption_count', ascending=False)
        .head(10)
        .reset_index(drop=True)
    )

    return top_10_eruptions_count

# %%
top_10_eruptions_count = load_top_10_eruptions_count(eruptions_and_types)
top_10_eruptions_count.style.background_gradient(cmap='YlOrRd', subset=['eruption_count'])
# Out:
# <style type="text/css">
# #T_19317_row0_col4 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_19317_row1_col4 {
#   background-color: #f84528;
#   color: #f1f1f1;
# }
# #T_19317_row2_col4 {
#   background-color: #fc612f;
#   color: #f1f1f1;
# }
# #T_19317_row3_col4 {
#   background-color: #fea546;
#   color: #000000;
# }
# #T_19317_row4_col4 {
#   background-color: #fecb67;
#   color: #000000;
# }
# #T_19317_row5_col4 {
#   background-color: #ffe48d;
#   color: #000000;
# }
# #T_19317_row6_col4 {
#   background-color: #fffcc5;
#   color: #000000;
# }
# #T_19317_row7_col4, #T_19317_row8_col4 {
#   background-color: #fffdc8;
#   color: #000000;
# }
# #T_19317_row9_col4 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# </style>
# <table id="T_19317">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19317_level0_col0" class="col_heading level0 col0" >volcano_name</th>
#       <th id="T_19317_level0_col1" class="col_heading level0 col1" >volcano_type</th>
#       <th id="T_19317_level0_col2" class="col_heading level0 col2" >first_eruption_year</th>
#       <th id="T_19317_level0_col3" class="col_heading level0 col3" >last_eruption_year</th>
#       <th id="T_19317_level0_col4" class="col_heading level0 col4" >eruption_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19317_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_19317_row0_col0" class="data row0 col0" >Etna</td>
#       <td id="T_19317_row0_col1" class="data row0 col1" >Stratovolcano(es)</td>
#       <td id="T_19317_row0_col2" class="data row0 col2" >-6190</td>
#       <td id="T_19317_row0_col3" class="data row0 col3" >2013</td>
#       <td id="T_19317_row0_col4" class="data row0 col4" >241</td>
#     </tr>
#     <tr>
#       <th id="T_19317_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_19317_row1_col0" class="data row1 col0" >Fournaise, Piton de la</td>
#       <td id="T_19317_row1_col1" class="data row1 col1" >Shield(s)</td>
#       <td id="T_19317_row1_col2" class="data row1 col2" >-2800</td>
#       <td id="T_19317_row1_col3" class="data row1 col3" >2020</td>
#       <td id="T_19317_row1_col4" class="data row1 col4" >194</td>
#     </tr>
#     <tr>
#       <th id="T_19317_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_19317_row2_col0" class="data row2 col0" >Asosan</td>
#       <td id="T_19317_row2_col1" class="data row2 col1" >Caldera(s)</td>
#       <td id="T_19317_row2_col2" class="data row2 col2" >-8050</td>
#       <td id="T_19317_row2_col3" class="data row2 col3" >2019</td>
#       <td id="T_19317_row2_col4" class="data row2 col4" >186</td>
#     </tr>
#     <tr>
#       <th id="T_19317_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_19317_row3_col0" class="data row3 col0" >Villarrica</td>
#       <td id="T_19317_row3_col1" class="data row3 col1" >Stratovolcano(es)</td>
#       <td id="T_19317_row3_col2" class="data row3 col2" >-7520</td>
#       <td id="T_19317_row3_col3" class="data row3 col3" >2014</td>
#       <td id="T_19317_row3_col4" class="data row3 col4" >164</td>
#     </tr>
#     <tr>
#       <th id="T_19317_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_19317_row4_col0" class="data row4 col0" >Asamayama</td>
#       <td id="T_19317_row4_col1" class="data row4 col1" >Complex(es)</td>
#       <td id="T_19317_row4_col2" class="data row4 col2" >-7200</td>
#       <td id="T_19317_row4_col3" class="data row4 col3" >2019</td>
#       <td id="T_19317_row4_col4" class="data row4 col4" >147</td>
#     </tr>
#     <tr>
#       <th id="T_19317_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_19317_row5_col0" class="data row5 col0" >Katla</td>
#       <td id="T_19317_row5_col1" class="data row5 col1" >Subglacial</td>
#       <td id="T_19317_row5_col2" class="data row5 col2" >-6380</td>
#       <td id="T_19317_row5_col3" class="data row5 col3" >1999</td>
#       <td id="T_19317_row5_col4" class="data row5 col4" >132</td>
#     </tr>
#     <tr>
#       <th id="T_19317_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_19317_row6_col0" class="data row6 col0" >Klyuchevskoy</td>
#       <td id="T_19317_row6_col1" class="data row6 col1" >Stratovolcano(es)</td>
#       <td id="T_19317_row6_col2" class="data row6 col2" >-3950</td>
#       <td id="T_19317_row6_col3" class="data row6 col3" >2019</td>
#       <td id="T_19317_row6_col4" class="data row6 col4" >111</td>
#     </tr>
#     <tr>
#       <th id="T_19317_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_19317_row7_col0" class="data row7 col0" >Merapi</td>
#       <td id="T_19317_row7_col1" class="data row7 col1" >Stratovolcano(es)</td>
#       <td id="T_19317_row7_col2" class="data row7 col2" >-8780</td>
#       <td id="T_19317_row7_col3" class="data row7 col3" >2018</td>
#       <td id="T_19317_row7_col4" class="data row7 col4" >110</td>
#     </tr>
#     <tr>
#       <th id="T_19317_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_19317_row8_col0" class="data row8 col0" >Mauna Loa</td>
#       <td id="T_19317_row8_col1" class="data row8 col1" >Shield(s)</td>
#       <td id="T_19317_row8_col2" class="data row8 col2" >-8050</td>
#       <td id="T_19317_row8_col3" class="data row8 col3" >1984</td>
#       <td id="T_19317_row8_col4" class="data row8 col4" >110</td>
#     </tr>
#     <tr>
#       <th id="T_19317_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_19317_row9_col0" class="data row9 col0" >Izu-Oshima</td>
#       <td id="T_19317_row9_col1" class="data row9 col1" >Stratovolcano(es)</td>
#       <td id="T_19317_row9_col2" class="data row9 col2" >-8450</td>
#       <td id="T_19317_row9_col3" class="data row9 col3" >1990</td>
#       <td id="T_19317_row9_col4" class="data row9 col4" >108</td>
#     </tr>
#   </tbody>
# </table>

# %%
eruptions_over_time = (
        eruptions_and_types.groupby(['year', 'volcano_name', 'volcano_type'])
        .size()
        .reset_index(name='eruption_count')
    )

eruptions_over_time
# Out:
#         year         volcano_name         volcano_type  eruption_count
# 0     -11345         Quetrupillan    Stratovolcano(es)               1
# 1     -10658         Quetrupillan    Stratovolcano(es)               1
# 2     -10450         Igwisi Hills  Pyroclastic cone(s)               1
# 3     -10060  Craters of the Moon  Pyroclastic cone(s)               1
# 4      -9950          Nemrut Dagi    Stratovolcano(es)               1
# ...      ...                  ...                  ...             ...
# 10567   2020     Kuchinoerabujima    Stratovolcano(es)               1
# 10568   2020   Rincon de la Vieja          Complex(es)               1
# 10569   2020           San Miguel    Stratovolcano(es)               1
# 10570   2020              Soputan    Stratovolcano(es)               1
# 10571   2020                 Taal           Caldera(s)               1
#
# [10572 rows x 4 columns]

# %%
top_10_volcanoes = top_10_eruptions_count['volcano_name']
filtered_eruptions = eruptions_over_time[eruptions_over_time['volcano_name'].isin(top_10_volcanoes)]

top_10_volcanoes, filtered_eruptions
# Out:
# (0                      Etna
#  1    Fournaise, Piton de la
#  2                    Asosan
#  3                Villarrica
#  4                 Asamayama
#  5                     Katla
#  6              Klyuchevskoy
#  7                    Merapi
#  8                 Mauna Loa
#  9                Izu-Oshima
#  Name: volcano_name, dtype: object,
#         year            volcano_name       volcano_type  eruption_count
#  34    -8780                  Merapi  Stratovolcano(es)               1
#  49    -8450              Izu-Oshima  Stratovolcano(es)               1
#  78    -8050                  Asosan         Caldera(s)               1
#  84    -8050              Izu-Oshima  Stratovolcano(es)               1
#  92    -8050               Mauna Loa          Shield(s)               1
#  ...     ...                     ...                ...             ...
#  10537  2019               Asamayama        Complex(es)               1
#  10538  2019                  Asosan         Caldera(s)               1
#  10542  2019  Fournaise, Piton de la          Shield(s)               2
#  10546  2019            Klyuchevskoy  Stratovolcano(es)               2
#  10566  2020  Fournaise, Piton de la          Shield(s)               1
#
#  [1387 rows x 4 columns])

# %%
plt.figure(figsize=(14, 8))
sns.lineplot(
        data=eruptions_over_time,
        x='year',
        y='volcano_name',
        hue='volcano_type',
        style='volcano_type',
        markers=True,
        dashes=False
    )
# Out:
# <Axes: xlabel='year', ylabel='volcano_name'>
